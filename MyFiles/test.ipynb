# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoVando/statistica-descrittiva-per-datascience/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("dsfsd")
# Out:
# [1] "dsfsd"
